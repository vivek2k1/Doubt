# %%
my_dict={'Key1':'Value1','Key2':'Value2'}
my_dict
# Out:
# {'Key1': 'Value1', 'Key2': 'Value2'}

# %%
my_dict['Key1']
# Out:
# 'Value1'

# %%
my_dict={'Roll_number':123,'Marks':[12,20,22],"Subject":['Maths','Physics','Chemistry']}
my_dict
# Out:
# {'Roll_number': 123,
#  'Marks': [12, 20, 22],
#  'Subject': ['Maths', 'Physics', 'Chemistry']}

# %%
my_dict['Subject']
# Out:
# ['Maths', 'Physics', 'Chemistry']

# %%
my_dict['Subject'][2]
# Out:
# 'Chemistry'

# %%
my_dict['Subject'][0].upper()
# Out:
# 'MATHS'

# %%
my_dict['Subject'][1].lower()
# Out:
# 'physics'

# %%
my_dict['Marks'][2]+=20
my_dict
# Out:
# {'Roll_number': 123,
#  'Marks': [12, 20, 42],
#  'Subject': ['Maths', 'Physics', 'Chemistry']}

# %%
my_dict['Marks'][0]-=10
my_dict
# Out:
# {'Roll_number': 123,
#  'Marks': [2, 20, 42],
#  'Subject': ['Maths', 'Physics', 'Chemistry']}

# %%
my_dict['Year']=['3rd','4th','5th']
my_dict
# Out:
# {'Roll_number': 123,
#  'Marks': [2, 20, 42],
#  'Subject': ['Maths', 'Physics', 'Chemistry'],
#  'Year': ['3rd', '4th', '5th']}

# %%
my_dict.update({'Roll_number':100})
my_dict
# Out:
# {'Roll_number': 100,
#  'Marks': [2, 20, 42],
#  'Subject': ['Maths', 'Physics', 'Chemistry'],
#  'Year': ['3rd', '4th', '5th']}

# %%
my_dict['Roll_number']+=23
my_dict
# Out:
# {'Roll_number': 123,
#  'Marks': [2, 20, 42],
#  'Subject': ['Maths', 'Physics', 'Chemistry'],
#  'Year': ['3rd', '4th', '5th']}

# %%
my_dict.update({'Subject'[0]:'Ashley'})
my_dict
# Out:
# {'Roll_number': 123,
#  'Marks': [2, 20, 42],
#  'Subject': 'Ashley',
#  'Year': ['3rd', '4th', '5th'],
#  'S': 'Ashley'}

# %%
my_dict
# Out:
# {'Roll_number': 123,
#  'Marks': [2, 20, 42],
#  'Subject': 'Ashley',
#  'Year': ['3rd', '4th', '5th'],
#  'S': 'Ashley'}

# %%
my_dict
# Out:
# {'Roll_number': 123,
#  'Marks': [2, 20, 42],
#  'Subject': 'Ashley',
#  'Year': ['3rd', '4th', '5th'],
#  'S': 'Ashley'}

# %%
i=13
if i<13:
    print('less than 13')
elif i>15:
    print('more than 15')
else:
    print('It is something else')
# Out:
# It is something else

# %%
i=91
j=23
if j>i:
    print('It is wrong')
else:
    print('It is not greater')
# Out:
# It is not greater

# %%
a=276575
b=230000
print('A') if a>b else print('B')
# Out:
# A

# %%
a=530
b=530
print('A') if a>b else print('B')if a==b else print('C')
# Out:
# B

# %%
a=200
b=33
c=500
if a>b and c<a:
    print('Both conditions are true')
else:
    print('Both are not true')
# Out:
# Both are not true

# %%
a=200
b=33
c=500
if a>b and c<a:
    print('Z')

# %%
marks=48
if marks>60:
    if marks>70:
        print('Distinction')
    else:
        print('First Class')
elif marks>50 and marks<=60:
    print('Second class')
elif marks>=35:
    print('Pass')
else:
    print('Fail')
# Out:
# Pass

# %%
num1='20'
num2=30
if num1=='20':
    print('A')
elif num2>25:
    print('B')
# Out:
# A

# %%
location=['Bangalore','Noida','Chennai','Delhi']
print(location)
# Out:
# ['Bangalore', 'Noida', 'Chennai', 'Delhi']

# %%
for x in location:
    print(x)
# Out:
# Bangalore
# Noida
# Chennai
# Delhi

# %%
salary=[2000,3000,4000,5000,7000,8000]
for value in salary:
    if value>5500:
        print(value)
# Out:
# 7000
# 8000

# %%
student_scores=[35,67,78,79,12,34,67,54,89]
for marks in student_scores:
    if marks>60:
        print('Distinction')
    else:
        print('First Class')
elif marks>50 and marks<=60:
    print('Second class')
elif marks>=35:
    print('Pass')
else:
    print('Fail')
# Out:
#   File "C:\Users\VKUMAR~1\AppData\Local\Temp/ipykernel_72572/311607416.py", line 7
#     elif marks>50 and marks<=60:
#     ^
# SyntaxError: invalid syntax

# %%
salary=[2000,4000,5000,6000,7000,8000]
for val in salary:
    if val>5500:
        print(val)
# Out:
# 6000
# 7000
# 8000

# %%
sal=[val for val in salary if val>5500]
sal
# Out:
# [6000, 7000, 8000]
